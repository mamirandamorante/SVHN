# %% [markdown]
# <a href="https://colab.research.google.com/github/mamirandamorante/SVHN/blob/main/Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Capstone Project
# ## Image classifier for the SVHN dataset
# ### Instructions
#
# In this notebook, you will create a neural network that classifies real-world images digits. You will use concepts from throughout this course in building, training, testing, validating and saving your Tensorflow classifier model.
#
# This project is peer-assessed. Within this notebook you will find instructions in each section for how to complete the project. Pay close attention to the instructions as the peer review will be carried out according to a grading rubric that checks key parts of the project instructions. Feel free to add extra cells into the notebook as required.
#
# ### How to submit
#
# When you have completed the Capstone project notebook, you will submit a pdf of the notebook for peer review. First ensure that the notebook has been fully executed from beginning to end, and all of the cell outputs are visible. This is important, as the grading rubric depends on the reviewer being able to view the outputs of your notebook. Save the notebook as a pdf (you could download the notebook with File -> Download .ipynb, open the notebook locally, and then File -> Download as -> PDF via LaTeX), and then submit this pdf for review.
#
# ### Let's get started!
#
# We'll start by running some imports, and loading the dataset. For this project you are free to make further imports throughout the notebook as you wish.

# %%
import tensorflow as tf
import random
import numpy as np
import pandas as pd
from scipy.io import loadmat
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# For the capstone project, you will use the [SVHN dataset](http://ufldl.stanford.edu/housenumbers/). This is an image dataset of over 600,000 digit images in all, and is a harder dataset than MNIST as the numbers appear in the context of natural scene images. SVHN is obtained from house numbers in Google Street View images.
#
# * Y. Netzer, T. Wang, A. Coates, A. Bissacco, B. Wu and A. Y. Ng. "Reading Digits in Natural Images with Unsupervised Feature Learning". NIPS Workshop on Deep Learning and Unsupervised Feature Learning, 2011.
#
# The train and test datasets required for this project can be downloaded from [here](http://ufldl.stanford.edu/housenumbers/train.tar.gz) and [here](http://ufldl.stanford.edu/housenumbers/test.tar.gz). Once unzipped, you will have two files: `train_32x32.mat` and `test_32x32.mat`. You should store these files in Drive for use in this Colab notebook.
#
# Your goal is to develop an end-to-end workflow for building, training, validating, evaluating and saving a neural network that classifies a real-world image into one of ten classes.

# %%
# Run this cell to connect to your Drive folder

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Load the dataset from your Drive folder

train = loadmat('/content/gdrive/MyDrive/path/to/train_32x32.mat')
test = loadmat('/content/gdrive/MyDrive/path/to/test_32x32.mat')

# %% [markdown]
# Both `train` and `test` are dictionaries with keys `X` and `y` for the input images and labels respectively.

# %% [markdown]
# ## 1. Inspect and preprocess the dataset
# * Extract the training and testing images and labels separately from the train and test dictionaries loaded for you.
# * Select a random sample of images and corresponding labels from the dataset (at least 10), and display them in a figure.
# * Convert the training and test images to grayscale by taking the average across all colour channels for each pixel. _Hint: retain the channel dimension, which will now have size 1._
# * Select a random sample of the grayscale images and corresponding labels from the dataset (at least 10), and display them in a figure.

# %%
#Extract the training and testing images and labels
X_train = train['X']
y_train = train['y']
X_test = test['X']
y_test = test['y']

print("Training Set", X_train.shape, y_train.shape)
print("Testing Set", X_test.shape, y_test.shape)
# Out:
# Training Set (32, 32, 3, 73257) (73257, 1)
# Testing Set (32, 32, 3, 26032) (26032, 1)

# %%
# Calculate the total number of images
num_images = X_train.shape[3] + X_test.shape[3]
print("Total Number of Images in the dataset:", num_images)
# Out:
# Total Number of Images in the dataset: 99289

# %%
X_train = X_train.astype('float64')
X_test = X_test.astype('float64')

y_train = y_train.astype('int64')
y_test = y_test.astype('int64')

X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
# Plot 10 training set images and its labels
for i in range(10):
    elde = random.randint(0,1000)
    plt.subplot(2,5,i+1)
    plt.title(str(y_train[elde]), fontsize=12) 
    plt.imshow(X_train[:,:,:,elde]) 
    plt.axis("off") 
plt.show()

# %%
#Convert trainint and test image sets from RGB to grayscale
X_train = np.average(X_train,axis = 2)
X_test = np.average(X_test,axis = 2)
print("Training Set", X_train.shape, y_train.shape)
print("Testing Set", X_test.shape, y_test.shape)
# Out:
# Training Set (32, 32, 73257) (73257, 1)
# Testing Set (32, 32, 26032) (26032, 1)

# %%
# Plot 10 training set images and its labels
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.title(str(y_train[i]), fontsize=12) 
    plt.imshow(X_train[:,:,i], cmap=plt.get_cmap('gray'))
    plt.axis("off") 
plt.show()

# %% [markdown]
# ## 2. MLP neural network classifier
# * Build an MLP classifier model using the Sequential API. Your model should use only Flatten and Dense layers, with the final layer having a 10-way softmax output.
# * You should design and build the model yourself. Feel free to experiment with different MLP architectures. _Hint: to achieve a reasonable accuracy you won't need to use more than 4 or 5 layers._
# * Print out the model summary (using the summary() method)
# * Compile and train the model (we recommend a maximum of 30 epochs), making use of both training and validation sets during the training run.
# * Your model should track at least one appropriate metric, and use at least two callbacks during training, one of which should be a ModelCheckpoint callback.
# * As a guide, you should aim to achieve a final categorical cross entropy training loss of less than 1.0 (the validation loss might be higher).
# * Plot the learning curves for loss vs epoch and accuracy vs epoch for both training and validation sets.
# * Compute and display the loss and accuracy of the trained model on the test set.

# %%
X_train_mlp = np.moveaxis(X_train, -1, 0)
X_test_mlp = np.moveaxis(X_test, -1, 0)
X_train_mlp =X_train_mlp[..., np.newaxis]
X_test_mlp = X_test_mlp[..., np.newaxis]
print("Training Set", X_train_mlp.shape, y_train.shape)
print("Testing Set", X_test_mlp.shape, y_test.shape)
# Out:
# Training Set (73257, 32, 32, 1) (73257, 1)
# Testing Set (26032, 32, 32, 1) (26032, 1)

# %%
def get_model(input_shape):
    model = Sequential([
        Dense(128,activation='relu',input_shape=input_shape,name='Dense1'),
        Dense(128,activation='relu',name='Dense2'),
        Flatten(name='Flatten'),
        Dense(64,activation='relu',name='Dense3'),
        Dense(11,activation='softmax',name='Dense4')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
model = get_model(X_train_mlp[0].shape)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Dense1 (Dense)               (None, 32, 32, 128)       256
# _________________________________________________________________
# Dense2 (Dense)               (None, 32, 32, 128)       16512
# _________________________________________________________________
# Flatten (Flatten)            (None, 131072)            0
# _________________________________________________________________
# Dense3 (Dense)               (None, 64)                8388672
# _________________________________________________________________
# Dense4 (Dense)               (None, 11)                715
# =================================================================
# Total params: 8,406,155
# Trainable params: 8,406,155
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Callbacks ModelCheckpoint and EarlyStopping
def get_checkpoint_best_only():
    checkpoint_best_only_path = 'checkpoints_best_only/checkpoint'
    checkpoint_best_only = ModelCheckpoint(filepath = checkpoint_best_only_path,
                                          save_weights_only=True,
                                          save_best_only=True,
                                          monitor = 'val_accuracy',
                                          verbose =1)
    return checkpoint_best_only

def get_early_stopping():
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=5)
    return callback

# %%
checkpoint_best_only = get_checkpoint_best_only()
#early_stopping = get_early_stopping()

# %%
callbacks = [checkpoint_best_only]
history = model.fit(X_train_mlp, y_train, epochs=30, validation_split=0.15,callbacks=callbacks,verbose=1)
# Out:
# Epoch 1/30
# 1946/1946 [==============================] - 17s 9ms/step - loss: 2.2004 - accuracy: 0.2078 - val_loss: 1.5171 - val_accuracy: 0.4831
#
# Epoch 00001: val_accuracy improved from -inf to 0.48312, saving model to checkpoints_best_only/checkpoint
# Epoch 2/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 1.4025 - accuracy: 0.5357 - val_loss: 1.2754 - val_accuracy: 0.5959
#
# Epoch 00002: val_accuracy improved from 0.48312 to 0.59587, saving model to checkpoints_best_only/checkpoint
# Epoch 3/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 1.2382 - accuracy: 0.6063 - val_loss: 1.2236 - val_accuracy: 0.6158
#
# Epoch 00003: val_accuracy improved from 0.59587 to 0.61580, saving model to checkpoints_best_only/checkpoint
# Epoch 4/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 1.1751 - accuracy: 0.6320 - val_loss: 1.1707 - val_accuracy: 0.6353
#
# Epoch 00004: val_accuracy improved from 0.61580 to 0.63527, saving model to checkpoints_best_only/checkpoint
# Epoch 5/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 1.1275 - accuracy: 0.6488 - val_loss: 1.1464 - val_accuracy: 0.6447
#
# Epoch 00005: val_accuracy improved from 0.63527 to 0.64474, saving model to checkpoints_best_only/checkpoint
# Epoch 6/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 1.1012 - accuracy: 0.6583 - val_loss: 1.1532 - val_accuracy: 0.6473
#
# Epoch 00006: val_accuracy improved from 0.64474 to 0.64728, saving model to checkpoints_best_only/checkpoint
# Epoch 7/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 1.0852 - accuracy: 0.6655 - val_loss: 1.1360 - val_accuracy: 0.6513
#
# Epoch 00007: val_accuracy improved from 0.64728 to 0.65129, saving model to checkpoints_best_only/checkpoint
# Epoch 8/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 1.0673 - accuracy: 0.6716 - val_loss: 1.1810 - val_accuracy: 0.6422
#
# Epoch 00008: val_accuracy did not improve from 0.65129
# Epoch 9/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 1.0509 - accuracy: 0.6771 - val_loss: 1.1111 - val_accuracy: 0.6574
#
# Epoch 00009: val_accuracy improved from 0.65129 to 0.65738, saving model to checkpoints_best_only/checkpoint
# Epoch 10/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 1.0507 - accuracy: 0.6772 - val_loss: 1.1147 - val_accuracy: 0.6618
#
# Epoch 00010: val_accuracy improved from 0.65738 to 0.66175, saving model to checkpoints_best_only/checkpoint
# Epoch 11/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 1.0374 - accuracy: 0.6815 - val_loss: 1.1480 - val_accuracy: 0.6478
#
# Epoch 00011: val_accuracy did not improve from 0.66175
# Epoch 12/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 1.0305 - accuracy: 0.6827 - val_loss: 1.1373 - val_accuracy: 0.6528
#
# Epoch 00012: val_accuracy did not improve from 0.66175
# Epoch 13/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 1.0164 - accuracy: 0.6863 - val_loss: 1.1197 - val_accuracy: 0.6652
#
# Epoch 00013: val_accuracy improved from 0.66175 to 0.66521, saving model to checkpoints_best_only/checkpoint
# Epoch 14/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 1.0087 - accuracy: 0.6917 - val_loss: 1.1380 - val_accuracy: 0.6538
#
# Epoch 00014: val_accuracy did not improve from 0.66521
# Epoch 15/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 1.0021 - accuracy: 0.6899 - val_loss: 1.0978 - val_accuracy: 0.6708
#
# Epoch 00015: val_accuracy improved from 0.66521 to 0.67076, saving model to checkpoints_best_only/checkpoint
# Epoch 16/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 0.9920 - accuracy: 0.6954 - val_loss: 1.1253 - val_accuracy: 0.6594
#
# Epoch 00016: val_accuracy did not improve from 0.67076
# Epoch 17/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 0.9920 - accuracy: 0.6928 - val_loss: 1.1309 - val_accuracy: 0.6533
#
# Epoch 00017: val_accuracy did not improve from 0.67076
# Epoch 18/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 0.9790 - accuracy: 0.6979 - val_loss: 1.1206 - val_accuracy: 0.6577
#
# Epoch 00018: val_accuracy did not improve from 0.67076
# Epoch 19/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 0.9790 - accuracy: 0.6981 - val_loss: 1.1317 - val_accuracy: 0.6601
#
# Epoch 00019: val_accuracy did not improve from 0.67076
# Epoch 20/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 0.9617 - accuracy: 0.7018 - val_loss: 1.1137 - val_accuracy: 0.6577
#
# Epoch 00020: val_accuracy did not improve from 0.67076
# Epoch 21/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 0.9616 - accuracy: 0.7055 - val_loss: 1.1195 - val_accuracy: 0.6554
#
# Epoch 00021: val_accuracy did not improve from 0.67076
# Epoch 22/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 0.9510 - accuracy: 0.7017 - val_loss: 1.1384 - val_accuracy: 0.6562
#
# Epoch 00022: val_accuracy did not improve from 0.67076
# Epoch 23/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 0.9460 - accuracy: 0.7045 - val_loss: 1.1489 - val_accuracy: 0.6524
#
# Epoch 00023: val_accuracy did not improve from 0.67076
# Epoch 24/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 0.9353 - accuracy: 0.7067 - val_loss: 1.1308 - val_accuracy: 0.6603
#
# Epoch 00024: val_accuracy did not improve from 0.67076
# Epoch 25/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 0.9337 - accuracy: 0.7104 - val_loss: 1.1353 - val_accuracy: 0.6598
#
# Epoch 00025: val_accuracy did not improve from 0.67076
# Epoch 26/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 0.9171 - accuracy: 0.7156 - val_loss: 1.1412 - val_accuracy: 0.6567
#
# Epoch 00026: val_accuracy did not improve from 0.67076
# Epoch 27/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 0.9169 - accuracy: 0.7128 - val_loss: 1.1664 - val_accuracy: 0.6509
#
# Epoch 00027: val_accuracy did not improve from 0.67076
# Epoch 28/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 0.9044 - accuracy: 0.7178 - val_loss: 1.1507 - val_accuracy: 0.6565
#
# Epoch 00028: val_accuracy did not improve from 0.67076
# Epoch 29/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 0.8960 - accuracy: 0.7181 - val_loss: 1.1517 - val_accuracy: 0.6553
#
# Epoch 00029: val_accuracy did not improve from 0.67076
# Epoch 30/30
# 1946/1946 [==============================] - 16s 8ms/step - loss: 0.8775 - accuracy: 0.7248 - val_loss: 1.1475 - val_accuracy: 0.6555
#
# Epoch 00030: val_accuracy did not improve from 0.67076

# %%
# Plot the training and validation loss

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %%
# Plot the training and validation loss

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ## 3. CNN neural network classifier
# * Build a CNN classifier model using the Sequential API. Your model should use the Conv2D, MaxPool2D, BatchNormalization, Flatten, Dense and Dropout layers. The final layer should again have a 10-way softmax output.
# * You should design and build the model yourself. Feel free to experiment with different CNN architectures. _Hint: to achieve a reasonable accuracy you won't need to use more than 2 or 3 convolutional layers and 2 fully connected layers.)_
# * The CNN model should use fewer trainable parameters than your MLP model.
# * Compile and train the model (we recommend a maximum of 30 epochs), making use of both training and validation sets during the training run.
# * Your model should track at least one appropriate metric, and use at least two callbacks during training, one of which should be a ModelCheckpoint callback.
# * You should aim to beat the MLP model performance with fewer parameters!
# * Plot the learning curves for loss vs epoch and accuracy vs epoch for both training and validation sets.
# * Compute and display the loss and accuracy of the trained model on the test set.

# %%
def get_model_cnn(input_shape):
    model = Sequential([
        Conv2D(filters=16, input_shape=(32, 32, 3), kernel_size=(3, 3),activation='relu', name='conv_1'),
        Conv2D(filters=8, kernel_size=(3, 3), activation='relu', name='conv_2'),
        MaxPooling2D(pool_size=(4, 4), name='pool_1'),    
        BatchNormalization(), 
        Flatten(name='flatten'),
        Dense(units=32, activation='relu', name='dense_1'),
        Dropout(0.5),
        Dense(units=10, activation='softmax', name='dense_2')
    ])  
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return cnn_model

# %%
history = model.fit(X_train_mlp, y_train, epochs=30, batch_size = 64, validation_split=0.15,verbose=1, callbacks=callbacks)
# Out:
# Epoch 1/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.8512 - accuracy: 0.7342 - val_loss: 1.1586 - val_accuracy: 0.6598
#
# Epoch 00001: val_accuracy did not improve from 0.67076
# Epoch 2/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.8492 - accuracy: 0.7335 - val_loss: 1.1743 - val_accuracy: 0.6584
#
# Epoch 00002: val_accuracy did not improve from 0.67076
# Epoch 3/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.8457 - accuracy: 0.7347 - val_loss: 1.1607 - val_accuracy: 0.6585
#
# Epoch 00003: val_accuracy did not improve from 0.67076
# Epoch 4/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.8410 - accuracy: 0.7354 - val_loss: 1.1809 - val_accuracy: 0.6572
#
# Epoch 00004: val_accuracy did not improve from 0.67076
# Epoch 5/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.8342 - accuracy: 0.7382 - val_loss: 1.1963 - val_accuracy: 0.6561
#
# Epoch 00005: val_accuracy did not improve from 0.67076
# Epoch 6/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.8247 - accuracy: 0.7405 - val_loss: 1.1841 - val_accuracy: 0.6569
#
# Epoch 00006: val_accuracy did not improve from 0.67076
# Epoch 7/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.8148 - accuracy: 0.7441 - val_loss: 1.1765 - val_accuracy: 0.6607
#
# Epoch 00007: val_accuracy did not improve from 0.67076
# Epoch 8/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.8062 - accuracy: 0.7470 - val_loss: 1.2027 - val_accuracy: 0.6495
#
# Epoch 00008: val_accuracy did not improve from 0.67076
# Epoch 9/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.7985 - accuracy: 0.7491 - val_loss: 1.1969 - val_accuracy: 0.6546
#
# Epoch 00009: val_accuracy did not improve from 0.67076
# Epoch 10/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.7880 - accuracy: 0.7506 - val_loss: 1.1894 - val_accuracy: 0.6608
#
# Epoch 00010: val_accuracy did not improve from 0.67076
# Epoch 11/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.7791 - accuracy: 0.7556 - val_loss: 1.2102 - val_accuracy: 0.6565
#
# Epoch 00011: val_accuracy did not improve from 0.67076
# Epoch 12/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.7724 - accuracy: 0.7572 - val_loss: 1.1883 - val_accuracy: 0.6592
#
# Epoch 00012: val_accuracy did not improve from 0.67076
# Epoch 13/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.7648 - accuracy: 0.7586 - val_loss: 1.2113 - val_accuracy: 0.6546
#
# Epoch 00013: val_accuracy did not improve from 0.67076
# Epoch 14/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.7557 - accuracy: 0.7603 - val_loss: 1.2439 - val_accuracy: 0.6559
#
# Epoch 00014: val_accuracy did not improve from 0.67076
# Epoch 15/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.7505 - accuracy: 0.7622 - val_loss: 1.2140 - val_accuracy: 0.6554
#
# Epoch 00015: val_accuracy did not improve from 0.67076
# Epoch 16/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.7441 - accuracy: 0.7646 - val_loss: 1.2535 - val_accuracy: 0.6547
#
# Epoch 00016: val_accuracy did not improve from 0.67076
# Epoch 17/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.7389 - accuracy: 0.7668 - val_loss: 1.2554 - val_accuracy: 0.6552
#
# Epoch 00017: val_accuracy did not improve from 0.67076
# Epoch 18/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.7319 - accuracy: 0.7680 - val_loss: 1.2703 - val_accuracy: 0.6597
#
# Epoch 00018: val_accuracy did not improve from 0.67076
# Epoch 19/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.7239 - accuracy: 0.7689 - val_loss: 1.2642 - val_accuracy: 0.6582
#
# Epoch 00019: val_accuracy did not improve from 0.67076
# Epoch 20/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.7164 - accuracy: 0.7741 - val_loss: 1.2876 - val_accuracy: 0.6541
#
# Epoch 00020: val_accuracy did not improve from 0.67076
# Epoch 21/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.7136 - accuracy: 0.7733 - val_loss: 1.3009 - val_accuracy: 0.6508
#
# Epoch 00021: val_accuracy did not improve from 0.67076
# Epoch 22/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.7080 - accuracy: 0.7747 - val_loss: 1.3058 - val_accuracy: 0.6476
#
# Epoch 00022: val_accuracy did not improve from 0.67076
# Epoch 23/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.7010 - accuracy: 0.7767 - val_loss: 1.2913 - val_accuracy: 0.6445
#
# Epoch 00023: val_accuracy did not improve from 0.67076
# Epoch 24/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.6955 - accuracy: 0.7785 - val_loss: 1.2957 - val_accuracy: 0.6522
#
# Epoch 00024: val_accuracy did not improve from 0.67076
# Epoch 25/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.6878 - accuracy: 0.7812 - val_loss: 1.3186 - val_accuracy: 0.6456
#
# Epoch 00025: val_accuracy did not improve from 0.67076
# Epoch 26/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.6821 - accuracy: 0.7814 - val_loss: 1.3396 - val_accuracy: 0.6448
#
# Epoch 00026: val_accuracy did not improve from 0.67076
# Epoch 27/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.6749 - accuracy: 0.7840 - val_loss: 1.3524 - val_accuracy: 0.6481
#
# Epoch 00027: val_accuracy did not improve from 0.67076
# Epoch 28/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.6700 - accuracy: 0.7852 - val_loss: 1.3830 - val_accuracy: 0.6481
#
# Epoch 00028: val_accuracy did not improve from 0.67076
# Epoch 29/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.6657 - accuracy: 0.7879 - val_loss: 1.4054 - val_accuracy: 0.6461
#
# Epoch 00029: val_accuracy did not improve from 0.67076
# Epoch 30/30
# 973/973 [==============================] - 12s 13ms/step - loss: 0.6624 - accuracy: 0.7869 - val_loss: 1.3745 - val_accuracy: 0.6425
#
# Epoch 00030: val_accuracy did not improve from 0.67076

# %%
# Plot the training and validation loss

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %%
# Plot the training and validation loss

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ## 4. Get model predictions
# * Load the best weights for the MLP and CNN models that you saved during the training run.
# * Randomly select 5 images and corresponding labels from the test set and display the images with their labels.
# * Alongside the image and label, show each model’s predictive distribution as a bar chart, and the final model prediction given by the label with maximum probability.
